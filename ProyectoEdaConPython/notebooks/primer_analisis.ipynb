# %% [markdown]
# # Primer Análisis
#
# Plantilla básica para empezar el Análisis Exploratorio de Datos (EDA).
#
# Instrucciones: coloca tus datos en ../data y ajusta la ruta en las llamadas a pd.read_csv().

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos (descomenta y ajusta la ruta)
# df = pd.read_csv('../data/tu_archivo.csv')

# Primeras filas
# df.head()
